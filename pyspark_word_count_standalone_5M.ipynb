# %%
"""
Created by Terry (terrydurunkai@gmail.com) on 2022/10/7.
"""

from pyspark import SparkContext


sc = SparkContext.getOrCreate()
# words = sc.textFile("gutenberg-1G.txt").flatMap(lambda line: line.split(" "))
words = sc.textFile("5000-8.txt").flatMap(lambda line: line.split(" "))
wordCounts = words.map(lambda word: (word, 1)).reduceByKey(lambda a,b:a +b)

# %%
# words = {}
# with open("output/part-00000", mode="r") as f:
#     lines = f.readlines()
#     for line in lines:
wordsMap = wordCounts.collectAsMap()
resultMap = {}
minCount = 1000
maxCount = 0
minWord = []
maxWord = []
for key in wordsMap.keys():
    flag = True
    for c in key:
        if ord(c) < 33 or ord(c) > 122:
            flag = False
            break
    if flag:
        resultMap[key] = wordsMap[key]
        if wordsMap[key] <= minCount:
            if wordsMap[key] == minCount:
                minWord.append(key)
            else:
                minWord = [key]
                minCount = wordsMap[key]
        if wordsMap[key] >= maxCount:
            if wordsMap[key] == maxCount:
                maxWord.append(key)
            else:
                maxWord = [key]
                maxCount = wordsMap[key]
print(minWord, end="")
print(" is the word(s) with the minimum count of %d" % (minCount))
print(maxWord, end="")
print(" is the word(s) with the maximum count of %d" % (maxCount))
# Out:
# ['EBook', '(#3', 'Vinci)', 'downloading', 'redistributing', 'eBook.', 'viewing', 'edit', '"legal', 'print,"', 'Included', 'specific', 'rights', 'restrictions', '**Welcome', 'Free', 'Plain', 'Vanilla', 'Electronic', 'Texts**', '**eBooks', 'Readable', 'Humans', 'Computers,', '1971**', '*****These', 'Were', 'Prepared', 'Thousands', 'Volunteers!*****', 'Author:', 'Release', 'Date:', 'Jan,', '[EBook', '#5000]', '[Yes,', 'ahead', 'schedule]', '[This', '2002]', 'Edition:', '09', 'Language:', 'Character', 'encoding:', 'UTF-8', 'START', 'Aldarondo', 'Distributed', 'Proofreaders', 'team.', 'PREFACE.', 'fatality', 'destiny', 'completed,', 'arisen', 'life-time,', 'unfinished;', 'Monument', 'Wall-painting', 'third--the', 'Milan--has', 'irremediable', 'decay', 'restorations', 'recklessly', 'XVIIIth', 'Nevertheless,', 'wellknown', 'description.', 'rightly,', '"that', 'laboured', 'deed",', 'unpublished,', 'forgotten.', 'appreciated.', 'prices', 'commanded,', 'Manuscript.', 'That,', 'eagerness', 'mystery,', 'phrases,', 'readings,', 'writing:', 'characters,', 'them".', 'Speaking', 'fatiguing', 'inconvenient', 'advisable,', 'deciphered.', 'Oriental', 'backwards--that', 'left--the', 'insuperable.', 'mastering', 'amalgamating', 'arbitrarily', 'halves;', 'regulate', 'sentences,', 'accents--and', 'beginner.', 'intentions', 'reverent', 'admirers', 'enquirer,', 'analytical', 'dissertations.', 'collated', 'research--as', 'me--was', 'confusion;', 'astronomy,', 'intestines,', 'forth.', 'intentions.', 'labyrinth;', 'collector', 'volumes,', 'concerned,', 'indifference', 'exceptions', '"turn', 'over",', 'page",', 'should,', 'writings?', 'completeness.', 'authoritative', 'arising', 'insuperable;', 'well-planned', 'especial', 'task.', 'thirty-seventh', 'interruption', 'indicated,', 'evident.', 'production,', 'verify', 'registered.', 'Index,', '1566)', 'ascertain,', 'index,', 'sheets--so', 'subject-matter', 'Mechanics,', 'specialists.', 'Dufresne,', 'two-and-twenty', 'languages.', 'mutilated,', 'fragmentary.', 'Library;', 'Manzi,', '1817,', 'Ludwig,', 'responsible,', 'portions--such', 'figure--are', 'genuine,', 'substitute,', 'scheme;', 'chaotic', 'derived;', 'scheme.', 'compiler,', 'editors,', 'injudiciously', 'order--or', 'enquirers,', 'till,', 'enabled,', 'liberality', 'inspect', 'best-known', 'Place.', 'only--but', 'fragment--inciting', 'Trattato.', 'enabled', 'prosecute,', 'unrestricted', '"photogravure".', 'Her', 'graciously', 'accorded', 'Commission', 'Centrale', 'Administrative', 'Sir', 'Frederic', 'Leighton,', 'Corresponding', 'Leicester,', 'Trivulsi,', 'Curators', 'Manzoni', 'owners', "Leonardo's;", 'Directors', 'Paris;', 'Turin;', 'Kensington', 'Librarians', 'Lalanne,', 'Abbate', 'Ceriani,', 'Maude', 'Thompson,', 'Keeper', 'Holmes,', 'Queens', 'Vere', 'Bayne,', 'Napier,', 'Holkham', 'Hall.', 'press,', 'Morelli,', 'Regno,', 'Frizzoni,', 'difficulties,', 'English,', 'Mrs.', 'Bell;', 'indefatigable', 'Poynter', 'revision', 'Henri', 'Geymuller,', 'illustrations,', 'negatives', '"photo-gravures"', 'Dujardin', 'duration,', 'tenour', 'unfortunate', 'Philosopher,', 'Naturalist.', 'teachings', 'contemporaries.', 'extraordinary', 'unjustly', 'accused', 'squandered', 'powers,', 'aside.', 'elucidation', 'Unity', 'Nature"', 'Berlin,', 'genius:', '"Majestati', 'naturae', 'ingenium."', 'LONDON,', '1883.', 'CONTENTS', 'VOLUME', 'PROLEGOMENA', 'Clavis', 'Sigillorum', 'Index', 'Manuscripts.--The', '(1).--The', '(2).--Admonition', 'readers', '(3).--The', '(4).--Suggestions', '(5--8).--General', '(9--13).--The', '(14--17).--The', '(18).--Necessity', '(19,', '20).--The', '(21--23).--Variability', '(24).--Focus', '(25).--Differences', '(26--29).--The', '(30--39).', '(40--41).--The', 'perspective:--of', '(42--46).--Of', '(47--48).--The', '(49).--Definition', '(50).--The', '(51).--Experimental', '(52--55).--The', '(55--56).--How', '(57).--The', '(58--64).--Proof', '(65--66).--General', '(67).--That', '(68).--A', '(69).--The', '(70--71).--The', '(72--73).--Refraction', '(74 ...
# ['the'] is the word(s) with the maximum count of 20583

# %%
wordCounts = sc.parallelize([resultMap])
wordCounts.saveAsTextFile("output/")
